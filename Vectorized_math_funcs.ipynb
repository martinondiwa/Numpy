# %%
# Element- Wise arithmatic
#we can apply operation beween two single elements within two arrays with element wise arithmatic

array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

#adding individual elements in the array

print(array1 +array2)
# Out:
# [5 7 9]

# %%
import numpy as np

# %%
# vectorized math funcs

# %%
array = np.array([1, 2, 3])

#getting the squaroot of the elements
print(np.sqrt(array))

#getting the exponential of the elements
print(np.exp(array))
# Out:
# [1.         1.41421356 1.73205081]
# [ 2.71828183  7.3890561  20.08553692]

# %%
array = np.array([2.34, 1.45, 7.7])

#rounding off
print(np.round(array))
# Out:
# [2. 1. 8.]

# %%
# ceiling (rounding up)

array = np.array([3.4, 2.1, 7.7])

print(np.ceil(array))
# Out:
# [4. 3. 8.]

# %%
#printing pi
print(np.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# **Exercise with vectorized math functions**

# %%
#given the radius of circles as an array get the areas of the circle
radii = np.array([1, 2, 3])

print (np.pi * radii**2)
# Out:
# [ 3.14159265 12.56637061 28.27433388]

# %%
# Element- Wise arithmatic
#we can apply operation beween two single elements within two arrays with element wise arithmatic

array1 = np.array([1, 2, 3])
array2 = np.array([4, 5, 6])

#adding individual elements in the array

print(array1 +array2)
# Out:
# [5 7 9]
